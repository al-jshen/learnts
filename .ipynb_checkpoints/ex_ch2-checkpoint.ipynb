# %%
library('forecast');
library('astsa');
library('fpp2');
library('GGally');

# %%
help(gold)
# Out:
# gold                 package:forecast                  R Documentation
#
# s
#
# n:
#
#      Daily morning gold prices in US dollars. 1 January 1985 - 31 March
#      1989.
#
# e:
#
#      gold
#
# t:
#
#      Time series data
#
# s:
#
#      tsdisplay(gold)

# %%
autoplot(gold); autoplot(woolyrnq); autoplot(gas)
# Out:
# plot without title
# plot without title
# plot without title

# %%
frequency(gold); frequency(woolyrnq); frequency(gas)
# Out:
# [1] 1
# [1] 4
# [1] 52

# %%
which.max(gold)
# Out:
# [1] 770

# %%
tute1 <- read.csv('tute1.csv', header=1)
head(tute1)
# Out:
#   X      Sales  AdBudget GDP
# 1 Mar-81 1020.2 659.2    251.8
# 2 Jun-81  889.2 589.0    290.9
# 3 Sep-81  795.0 512.5    290.8
# 4 Dec-81 1003.9 614.1    292.4
# 5 Mar-82 1057.7 647.2    279.1
# 6 Jun-82  944.4 602.0    254.0

# %%
ts1 <- ts(tute1[,-1], start=1981, frequency=4)
autoplot(ts1)
# Out:
# plot without title

# %%
help(usdeaths)
# Out:
# usdeaths                  package:fma                  R Documentation
#
# A
#
# n:
#
#      Monthly accidental deaths in USA.
#
# e:
#
#      usdeaths
#
# t:
#
#      Time series data
#
# e:
#
#      Makridakis, Wheelwright and Hyndman (1998) _Forecasting: methods
#      and applications_, John Wiley & Sons: New York. Exercises 2.3 and
#      2.4.
#
# s:
#
#      plot(usdeaths)
#      seasonplot(usdeaths)
#      tsdisplay(usdeaths)

# %%
plot(usdeaths, xlab='year', ylab='number of deaths', main='monthly accidental deaths in usa')
# Out:
# Plot with title “monthly accidental deaths in usa”

# %%
autoplot(hsales)
# Out:
# plot without title

# %%
ggseasonplot(hsales)
# Out:
# plot without title

# %%
ggsubseriesplot(hsales)
# Out:
# plot without title

# %%
gglagplot(hsales)
# Out:
# plot without title

# %%
acf(hsales)
# Out:
# Plot with title “Series  hsales”

# %%
plot(diff(hsales))
# Out:
# plot without title

# %%
acf(diff(hsales))
# Out:
# Plot with title “Series  diff(hsales)”

# %%
autoplot(arrivals, facets=TRUE)
# Out:
# plot without title

# %%
par(mfrow=c(4,1))
ggseasonplot(arrivals[,1])
ggseasonplot(arrivals[,2])
ggseasonplot(arrivals[,3])
ggseasonplot(arrivals[,4])
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
plot(dj)
# Out:
# plot without title

# %%
plot(diff(dj))
# Out:
# plot without title

# %%
acf(diff(dj))
# Out:
# Plot with title “Series  diff(dj)”
